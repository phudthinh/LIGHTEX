-- %% [markdown]
-- # [dbo].[ACCOUNT]

-- %%
USE [LIGHTEX]
GO

-- %%
/****** Object:  Table [dbo].[ACCOUNT]    Script Date: 4/20/2023 5:17:04 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ACCOUNT](
	[username] [nvarchar](50) NOT NULL,
	[password] [nvarchar](max) NOT NULL,
	[full_name] [nvarchar](50) NOT NULL,
	[active] [bit] NOT NULL,
	[permission] [int] NOT NULL,
	[last_login] [datetime] NOT NULL,
	[create_date] [datetime] NOT NULL,
 CONSTRAINT [PK_ACCOUNT_username] PRIMARY KEY CLUSTERED 
(
	[username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BILL]

-- %%
/****** Object:  Table [dbo].[BILL]    Script Date: 4/20/2023 5:17:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BILL](
	[id_bill] [int] IDENTITY(1,1) NOT NULL,
	[id_customer] [int] NOT NULL,
	[id_product] [int] NOT NULL,
	[quantity] [int] NOT NULL,
	[status] [int] NOT NULL,
	[payments] [int] NOT NULL,
	[create_date] [datetime] NOT NULL,
	[ship_date] [datetime] NOT NULL,
 CONSTRAINT [PK_BILL_id_bill] PRIMARY KEY CLUSTERED 
(
	[id_bill] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BRAND]

-- %%
/****** Object:  Table [dbo].[BRAND]    Script Date: 4/20/2023 5:17:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BRAND](
	[id_brand] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](50) NOT NULL,
	[description] [nvarchar](500) NOT NULL,
 CONSTRAINT [PK_BRAND_id_brand] PRIMARY KEY CLUSTERED 
(
	[id_brand] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CART]

-- %%
/****** Object:  Table [dbo].[CART]    Script Date: 4/20/2023 5:17:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CART](
	[id_cart] [int] IDENTITY(1,1) NOT NULL,
	[id_customer] [int] NOT NULL,
	[id_product] [int] NOT NULL,
	[quantity] [int] NOT NULL,
 CONSTRAINT [PK_CART_id_cart] PRIMARY KEY CLUSTERED 
(
	[id_cart] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CATEGORY]

-- %%
/****** Object:  Table [dbo].[CATEGORY]    Script Date: 4/20/2023 5:17:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CATEGORY](
	[id_category] [int] IDENTITY(1,1) NOT NULL,
	[name] [nvarchar](50) NOT NULL,
	[description] [nvarchar](500) NOT NULL,
	[icon] [varbinary](max) NOT NULL,
 CONSTRAINT [PK_CATEGORY_id_category] PRIMARY KEY CLUSTERED 
(
	[id_category] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[COMMENT]

-- %%
/****** Object:  Table [dbo].[COMMENT]    Script Date: 4/20/2023 5:17:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[COMMENT](
	[id_comment] [int] IDENTITY(1,1) NOT NULL,
	[id_customer] [int] NOT NULL,
	[id_product] [int] NOT NULL,
	[content] [nvarchar](500) NOT NULL,
	[star] [int] NOT NULL,
 CONSTRAINT [PK_COMMENT_id_comment] PRIMARY KEY CLUSTERED 
(
	[id_comment] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CUSTOMER]

-- %%
/****** Object:  Table [dbo].[CUSTOMER]    Script Date: 4/20/2023 5:17:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CUSTOMER](
	[id_customer] [int] IDENTITY(1,1) NOT NULL,
	[username] [nvarchar](50) NOT NULL,
	[email] [nvarchar](50) NULL,
	[phone] [nvarchar](12) NULL,
	[address] [nvarchar](200) NULL,
	[ward] [nvarchar](200) NULL,
	[city] [nvarchar](200) NULL,
	[avatar] [varbinary](max) NULL,
	[money] [float] NOT NULL,
 CONSTRAINT [PK_CUSTOMER_id_customer] PRIMARY KEY CLUSTERED 
(
	[id_customer] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FAVORITE]

-- %%
/****** Object:  Table [dbo].[FAVORITE]    Script Date: 4/20/2023 5:17:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FAVORITE](
	[id_favorite] [int] IDENTITY(1,1) NOT NULL,
	[id_customer] [int] NOT NULL,
	[id_product] [int] NOT NULL,
	[active] [bit] NOT NULL,
 CONSTRAINT [PK_FAVORITE_id_favorite] PRIMARY KEY CLUSTERED 
(
	[id_favorite] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HISTORY]

-- %%
/****** Object:  Table [dbo].[HISTORY]    Script Date: 4/20/2023 5:17:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HISTORY](
	[id_history] [int] IDENTITY(1,1) NOT NULL,
	[id_customer] [int] NOT NULL,
	[id_product] [int] NOT NULL,
 CONSTRAINT [PK_HISTORY_id_history] PRIMARY KEY CLUSTERED 
(
	[id_history] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PRODUCT]

-- %%
/****** Object:  Table [dbo].[PRODUCT]    Script Date: 4/20/2023 5:17:05 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PRODUCT](
	[id_product] [int] IDENTITY(1,1) NOT NULL,
	[id_category] [int] NOT NULL,
	[id_brand] [int] NOT NULL,
	[name] [nvarchar](50) NOT NULL,
	[information] [nvarchar](500) NOT NULL,
	[price] [float] NOT NULL,
	[image] [varbinary](max) NOT NULL,
	[effect] [int] NOT NULL,
	[status] [bit] NOT NULL,
	[create_date] [datetime] NOT NULL,
	[modified_date] [datetime] NOT NULL,
 CONSTRAINT [PK_PRODUCT_id_product] PRIMARY KEY CLUSTERED 
(
	[id_product] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ACCOUNT]

-- %%
INSERT [dbo].[ACCOUNT] ([username], [password], [full_name], [active], [permission], [last_login], [create_date]) VALUES (N'admin', N'8c6976e5b5410415bde908bd4dee15dfb167a9c873fc4bb8a81f6f2ab448a918', N'admin', 1, 1, CAST(N'2023-04-20T17:05:59.900' AS DateTime), CAST(N'2023-04-19T23:01:27.663' AS DateTime))
INSERT [dbo].[ACCOUNT] ([username], [password], [full_name], [active], [permission], [last_login], [create_date]) VALUES (N'test', N'688787d8ff144c502c7f5cffaafe2cc588d86079f9de88304c26b0cb99ce91c6', N'Yasuo', 1, 0, CAST(N'2023-04-19T23:12:18.427' AS DateTime), CAST(N'2023-04-19T23:09:33.183' AS DateTime))
GO

-- %% [markdown]
-- # [dbo].[BRAND]

-- %%
SET IDENTITY_INSERT [dbo].[BRAND] ON 
INSERT [dbo].[BRAND] ([id_brand], [name], [description]) VALUES (1, N'testtt', N'')
SET IDENTITY_INSERT [dbo].[BRAND] OFF
GO

-- %% [markdown]
-- # [dbo].[CATEGORY]

-- %%
SET IDENTITY_INSERT [dbo].[CATEGORY] ON 
INSERT [dbo].[CATEGORY] ([id_category], [name], [description], [icon]) VALUES (2, N'asdasd', N'asdasd', ...)
SET IDENTITY_INSERT [dbo].[CATEGORY] OFF
GO

-- %% [markdown]
-- # [dbo].[CUSTOMER]

-- %%
SET IDENTITY_INSERT [dbo].[CUSTOMER] ON 
INSERT [dbo].[CUSTOMER] ([id_customer], [username], [email], [phone], [address], [ward], [city], [avatar], [money]) VALUES (1, N'admin', N'', N'', N'', N'', N'', 0x, 0)
INSERT [dbo].[CUSTOMER] ([id_customer], [username], [email], [phone], [address], [ward], [city], [avatar], [money]) VALUES (4, N'test', N'bestdaxuovn@gmail.com', N'0857300073', N'10 Trân Nguyên Hãn', N'', N'Vùng Tàu', 0x, 0)
SET IDENTITY_INSERT [dbo].[CUSTOMER] OFF
GO

-- %% [markdown]
-- # [DF__COMMENT__star__52593CB8]

-- %%
ALTER TABLE [dbo].[COMMENT] ADD  DEFAULT ((0)) FOR [star]
GO

-- %% [markdown]
-- # [DF__CUSTOMER__money__398D8EEE]

-- %%
ALTER TABLE [dbo].[CUSTOMER] ADD  DEFAULT ((0)) FOR [money]
GO

-- %% [markdown]
-- # [DF__PRODUCT__price__412EB0B6]

-- %%
ALTER TABLE [dbo].[PRODUCT] ADD  DEFAULT ((0)) FOR [price]
GO

-- %% [markdown]
-- # [DF__PRODUCT__effect__4222D4EF]

-- %%
ALTER TABLE [dbo].[PRODUCT] ADD  DEFAULT ((0)) FOR [effect]
GO

-- %% [markdown]
-- # [FK__BILL__id_custome__4AB81AF0]

-- %%
ALTER TABLE [dbo].[BILL]  WITH CHECK ADD FOREIGN KEY([id_customer])
REFERENCES [dbo].[CUSTOMER] ([id_customer])
GO

-- %% [markdown]
-- # [FK__BILL__id_product__4BAC3F29]

-- %%
ALTER TABLE [dbo].[BILL]  WITH CHECK ADD FOREIGN KEY([id_product])
REFERENCES [dbo].[PRODUCT] ([id_product])
GO

-- %% [markdown]
-- # [FK__CART__id_custome__46E78A0C]

-- %%
ALTER TABLE [dbo].[CART]  WITH CHECK ADD FOREIGN KEY([id_customer])
REFERENCES [dbo].[CUSTOMER] ([id_customer])
GO

-- %% [markdown]
-- # [FK__CART__id_product__47DBAE45]

-- %%
ALTER TABLE [dbo].[CART]  WITH CHECK ADD FOREIGN KEY([id_product])
REFERENCES [dbo].[PRODUCT] ([id_product])
GO

-- %% [markdown]
-- # [FK__COMMENT__id_cust__534D60F1]

-- %%
ALTER TABLE [dbo].[COMMENT]  WITH CHECK ADD FOREIGN KEY([id_customer])
REFERENCES [dbo].[CUSTOMER] ([id_customer])
GO

-- %% [markdown]
-- # [FK__COMMENT__id_prod__5441852A]

-- %%
ALTER TABLE [dbo].[COMMENT]  WITH CHECK ADD FOREIGN KEY([id_product])
REFERENCES [dbo].[PRODUCT] ([id_product])
GO

-- %% [markdown]
-- # [FK__CUSTOMER__userna__3A81B327]

-- %%
ALTER TABLE [dbo].[CUSTOMER]  WITH CHECK ADD FOREIGN KEY([username])
REFERENCES [dbo].[ACCOUNT] ([username])
GO

-- %% [markdown]
-- # [FK__FAVORITE__id_cus__4E88ABD4]

-- %%
ALTER TABLE [dbo].[FAVORITE]  WITH CHECK ADD FOREIGN KEY([id_customer])
REFERENCES [dbo].[CUSTOMER] ([id_customer])
GO

-- %% [markdown]
-- # [FK__FAVORITE__id_pro__4F7CD00D]

-- %%
ALTER TABLE [dbo].[FAVORITE]  WITH CHECK ADD FOREIGN KEY([id_product])
REFERENCES [dbo].[PRODUCT] ([id_product])
GO

-- %% [markdown]
-- # [FK__HISTORY__id_cust__571DF1D5]

-- %%
ALTER TABLE [dbo].[HISTORY]  WITH CHECK ADD FOREIGN KEY([id_customer])
REFERENCES [dbo].[CUSTOMER] ([id_customer])
GO

-- %% [markdown]
-- # [FK__HISTORY__id_prod__5812160E]

-- %%
ALTER TABLE [dbo].[HISTORY]  WITH CHECK ADD FOREIGN KEY([id_product])
REFERENCES [dbo].[PRODUCT] ([id_product])
GO

-- %% [markdown]
-- # [FK__PRODUCT__id_bran__440B1D61]

-- %%
ALTER TABLE [dbo].[PRODUCT]  WITH CHECK ADD FOREIGN KEY([id_brand])
REFERENCES [dbo].[BRAND] ([id_brand])
GO

-- %% [markdown]
-- # [FK__PRODUCT__id_cate__4316F928]

-- %%
ALTER TABLE [dbo].[PRODUCT]  WITH CHECK ADD FOREIGN KEY([id_category])
REFERENCES [dbo].[CATEGORY] ([id_category])
GO
